# %% [markdown]
# # TP - Conversion d'un entier relatif

# %% [markdown]
# ## Exercice 1. Valeur absolue d'un entier
#
# Écrire une fonction ``valeur_absolue(entier)`` qui renvoie la valeur absolue du nombre passé en paramètre.
#
# ```python
# >>> valeur_absolue(7)
# 7
# >>> valeur_absolue(-6)
# 6
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 2. Inversion d'un entier en binaire
#
# Écrire une fonction `inverser(binaire)` qui renvoie une nouvelle chaîne de caractères qui correspond à l'inverse de la chaîne passée en paramètre.
#
# Le paramètre de la fonction sera une chaîne de caractères représentant un nombre écrit en base 2.
#
# ``` python
# >>> inverser('1010')
# '0101'
# >>> inverser('10110011')
# '01001100'
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 3. Addition binaire
#
# Écrire une fonction `addition_binaire(binaire1, binaire2)` qui additionne et renvoie le résultat des 2 nombres représentés en base 2. Vous vous aiderez de la table d'addition vu dans le cours.
#
# __N.B : On suppose que les 2 binaires comportent le même nombre de bits.__
#
# ```python
# >>> addition_binaire('1001', '0001')
# '1010'
# >>> addition_binaire('0001', '0001')
# '0010'
# >>> addition_binaire('0001', '1111')
# '0000'
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 4. Compléments à 2
#
# En utilisant les fonctions précédentes, écrire une fonction `complement_a_deux(entier, n)` qui renvoie la représentation en complément à 2 de l'__entier négatif__ donné en paramètre.
#
# ``` python
# >>> complement_a_deux(-1, 8)
# '11111111'
# >>> complement_a_deux(-12, 8)
# '11110100'
# >>> complement_a_deux(-128, 8)
# '10000000'
# ```
#
# __N.B : Il est possible d'utiliser la fonction `rjust` disponible pour le type `str` dont vous conculterez la documentation.__

# %%
# Réponse

# %% [markdown]
# ## Exercice 5. Compléments à 2 vers décimal
#
# En utilisant le principe inverse, écrire une fonction `complement_a_2_vers_decimal(binaire)` qui renvoie la valeur du nombre représenté en complément à 2 passé en paramètre.
#
# __N.B : Vous aurez besoin d'écrire une fonction qui effectue la soustraction de 2 nombres binaires.__
#
# ``` python
# >>> complement_a_deux_vers_decimal('1111')
# -1
# >>> complement_a_deux_vers_decimal('1010")
# -13
# ```

# %%
# Réponse

# %%
# Réponse

# %%
import doctest
doctest.testmod()
