# %% [markdown]
# # TP - Conversion entre bases de numération

# %% [markdown]
# ## Exercice 1. Validité d'un nombre écrit en binaire
#
# Écrire une fonction `est_valide(binaire)` qui renvoie :
#
# * **True** si le nombre est valide
# * **False** si le nombre est invalide.
# Le paramètre de la fonction sera une chaîne de caractères représentant un nombre écrit en base 2.
#
# ``` python
# >>> est_valide('100010101')
# True
# >>> est_valide('1010401034')
# False
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 2. Parité d'un nombre écrit en binaire
#
# Écrire une fonction ``est_pair(binaire)`` qui retourne :
#
# * **True** si le nombre passé en paramètre est pair
# * **False** si le nombre passé en paramètre est impair.
#
# Le paramètre de la fonction sera une chaîne de caractères représentant un nombre écrit en base 2.
#
# ```python
# >>> est_pair('1001')
# False
# >>> est_pair('1010')
# True
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 3. Valeur d'une puissance de 2
#
# Écrire une fonction `deux_puissance(rang)` qui renvoie la puissance de 2 associée au rang passé en paramètre. Vous n'utiliserez pas les fonctions Python déjà existantes.
#
# ``` python
# >>> deux_puissance(0)
# 1
# >>> deux_puissance(1)
# 2
# >>> deux_puissance(2)
# 4
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 4. Conversion binaire en décimale
#
# A l'aide des fonctions précédentes, écrire une fonction `binaire_en_decimal(binaire)` qui renvoie la valeur décimale du nombre passé en paramètre.
#
# Le paramètre sera une chaîne de caractères représentant un nombre binaire. On vérifiera que ce nombre binaire est valide.
#
# ``` python
# >>> binaire_en_decimal('1')
# 1
# >>> binaire_en_decimal('1010')
# 10
# >>> binaire_en_decimal('1001')
# 9
# >>> binaire_en_decimal('1201') is None
# True
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 5. Division Euclidienne
#
# Écrire une fonction `division_euclidienne(nombre, diviseur)` qui renvoie le quotient et le reste obtenu lorsque l'on divise le paramètre _nombre_ par le paramètre _diviseur_.
#
# ``` python
# >>> division_euclidienne(6, 3)
# (2, 0)
# >>> division_euclidienne(10, 4)
# (2, 2)
# >>> division_euclidienne(6, 0) is None
# True
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 6. Conversion décimale en binaire
#
# À l'aide de l'algorithme de la division euclidienne et des fonctions précédentes, écrire une fonction `decimal_en_binaire(decimal)` qui renvoie une chaîne de caractères correspondant à la représentation binaire du nombre passé en paramètre.
#
#
# ``` python
# >>> decimal_en_binaire(0)
# '0'
# >>> decimal_en_binaire(6)
# '110'
# >>> decimal_en_binaire(16)
# '10000'
# >>> decimal_en_binaire(31)
# '11111'
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 7. Symboles du système hexadécimal
#
# Écrire une fonction `symbole_hexa(decimal)` qui renvoie le symbole correspondant au paramètre dans la base 16.
#
# ```python
# >>> symbole_hexa(1)
# '1'
# >>> symbole_hexa(10)
# 'A'
# >>> symbole_hexa(15)
# 'F'
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 8. Conversion décimale en hexadécimal
#
# En s'inspirant des questions précédentes, écrire une fonction ``decimal_en_hexa(decimal)`` qui renvoie une chaîne de caractères correspondant à la représentation en base 16 du nombre passé en paramètre.
#
# ``` python
# >>> decimal_en_hexa(2)
# '2'
# >>> decimal_en_hexa(10)
# 'A'
# >>> decimal_en_hexa(21)
# '15'
# >>> decimal_en_hexa(2019)
# '7E3'
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 9. Valeur d'un symbole du système hexadécimal
#
# Écrire une fonction `valeur_symbole(hexa)` qui renvoie la valeur du symbole correspondant au paramètre dans la base 16.
#
# ```python
# >>> valeur_symbole('0')
# 0
# >>> valeur_symbole('9')
# 9
# >>> valeur_symbole('A')
# 10
# >>> valeur_symbole('F')
# 15
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 10. Conversion hexadécimale en décimal
#
# Écrire une fonction `hexa_en_decimal(hexa)` qui renvoie le nombre correspondant à la représentation en base 10 du nombre passé en paramètre.
#
# ```python
# >>> hexa_en_decimal('2')
# 10
# >>> hexa_en_decimal('A')
# 10
# >>> hexa_en_decimal('E10F')
# 57615
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 11. Conversion décimal en une base $n$
#
# En s'inspirant des exercies précédents, écrire une fonction `decimal_en_base_n(decimal, n)` qui renvoie une chaîne de caractères correspondant à la représentation en base $n$ du nombre passé en paramètre.
#
# $n$ est un entier strictement supérieur à 1.
#
# ```python
# >>> decimal_en_base_n(10, 2)
# '1010'
# >>> decimal_en_base_n(10, 16)
# 'A'
# >>> decimal_en_base_n(10, 5)
# '20'
# >>> decimal_en_base_n(10, 1) is None
# True
# ```

# %%
# Réponse

# %%
import doctest
doctest.testmod()
