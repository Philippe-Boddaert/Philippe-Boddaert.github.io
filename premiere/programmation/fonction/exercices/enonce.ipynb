# %% [markdown]
# # Exercices - Les fonctions

# %% [markdown]
# ## Exercice 1. Parité d'un entier
#
# Écrire un __prédicat__ `est_pair` qui indique si l'entier `n` passé en paramètre est pair ou non.
#
# _Exemples d'utilisation_ :
#
# ```python
# >>> est_pair(1)
# False
# >>> est_pair(2)
# True
# >>> est_pair(7)
# False
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 2. Imparité d'un entier
#
# Écrire un __prédicat__ `est_impair` qui indique si l'entier `n` passé en paramètre est impair ou non.
#
# _Exemples d'utilisation_ :
#
# ```python
# >>> est_impair(1)
# True
# >>> est_impair(2)
# False
# >>> est_impair(7)
# True
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 3. Voyelle
#
# Écrire un prédicat `est_voyelle` qui indique si le caractère `c` passé en paramètre est une voyelle ou non.
#
# _Exemples d'utilisation_ :
#
# ```python
# >>> est_voyelle("e")
# True
# >>> est_voyelle("N")
# False
# >>> est_voyelle("A")
# True
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 4. Énergie cinétique
#
# L'énergie cinétique (en Joules) d'un objet de masse $m$ (en Kg) se déplaçant à la vitesse $v$ (en m/s) s'exprime par la fonction suivante :
#
# $$Ec = \frac{1}{2} m v^{2}$$
#
# Écrire une fonction `calculer_energie` qui calcule l'énergie cinétique d'un objet dont la masse `m` et la vitesse `v` sont passés en paramètre.
#
# _Exemples d'utilisation_ :
#
# ```python
# >>> calculer_energie(1, 2)
# 2.0
# >>> calculer_energie(65, 0.2)
# 1.3000000000000003
# >>> calculer_energie(0.001, 300000000) # 300000000 m/s correspond à la vitesse de la lumière
# 45000000000000.0
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 5. Conversion Celsius en Fahrenheit
#
# Aujourd'hui, l'échelle des degrés Fahrenheit est liée à l'échelle degrés Celsius par la relation :
#
# $$T(°F)=\frac{9}{5}T(°C)+32$$
#
# Écrire une fonction `fahrenheit` qui étant donnée une `température` donnée en Celsius renvoie la valeur équivalente en degré Fahrenheit.
#
# _Exemples d'utilisation_ :
#
# ```python
# >>> fahrenheit(0)
# 32.0
# >>> fahrenheit(37.8)
# 100.03999999999999
# >>> fahrenheit(100)
# 212.0
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 6. Conversion Fahrenheit en Celsius
#
# En adaptant la formule de l'exercice précédent, écrire une fonction `celsius` qui étant donnée une `température` donnée en Fahrenheit renvoie la valeur équivalente en degré Celsius.
#
# _Exemples d'utilisation_ :
#
# ```python
# >>> celsius(32.0)
# 0.0
# >>> celsius(100)
# 37.77777777777778
# >>> celsius(212.0)
# 100.0
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 7. Codage L33T SP34K
#
# Le leet speak consiste à écrire des mots en remplaçant des lettres par la forme d'un chiffre voisin de la lettre.
#
# Exemple : `UN 54V4NT 14NG4G3 C0DÉ` est la version leet de `UN SAVANT LANGAGE CODÉ`
#
# Les caractères `A` sont remplacées par le caractère `4`, tandis que `L` est remplacé par `1`, `E` par `3` et `O` par `0`.
#
# Écrire une une fonction `coder_leet` qui prend une `chaine` de caractères en entrée et renvoie la chaine codée en leet speak.

# %% [markdown]
# N.B : Ci-dessous la correspondance des lettres en leet speak
#
# | Lettre | O | L | E | A | S | G | T | B | P |
# | :--: | :--: | :--: | :--: | :--: | :--: | :--: | :--: | :--: | :--: |
# | Correspondance en leet speak | 0 | 1 | 3 | 4 | 5 | 6 | 7 | 8 | 9 |

# %%
# Réponse

# %% [markdown]
# ## Exercice 8. Décodage L33T SP34K
#
# Écrire une fonction `decoder_leet` qui prend une `chaine` de caractères codée leet speak en entrée et renvoie la chaine décodée.

# %%
# Réponse
