# %% [markdown]
# # Exercices - Les fonctions

# %% [markdown]
# ## Exercice 1. Indice d'un caractère
#
# On souhaite disposer d'une fonction qui renvoie l'indice d'un caractère particulier dans une chaine de caractères.
#
# N.B : Si le caractère apparait plusieurs fois dans la chaine, on renvoie l'indice de sa __première apparition__.
#
# Exemple : Soit la chaine de caractères $c$ égale à `"toutou"`
#
# - L'indice du caractère `t` dans $c$ est 0, car `t` est la première lettre de `toutou`,
# - L'indice du caractère `u` dans $c$ est 2, car `u` est la trosième lettre de `toutou`,
# - L'indice du caractère `e` dans $c$ est -1, car `e` n'apparait pas dans `toutou`.
#
# Écrire une fonction `indice` qui renvoie l'indice d'un caractère dans une chaine, passés en paramètre. Si le caractère n'apparait pas, la fonction renvoie -1.

# %%
# Réponse

# %% [markdown]
# ## Exercice 2. Occurrences
#
# On souhaite disposer d'une fonction qui compte le nombre d'__occurrences__ d'un caractère dans une chaine de caractères.
#
# Exemple : Soit la chaine de caractères $c$ égale à `"toutou"`.
#
# Le nombre d'occurences de `t` est de 2, tandis que le nombre d'occurrences de `e` est de 0.
#
# Écrire une fonction `nombre_occurrences` qui renvoie le nombre d'occurrences d'un caractère dans une chaine, passés en paramètre.

# %%
# Réponse

# %% [markdown]
# ## Exercice 3. Présence d'un caractère
#
# On souhaite disposer d'une fonction qui indique si un caractère apparait dans une chaine de caractères.
#
# Exemple : Soit la chaine de caractères $c$ égale à `"toutou"`.
#
# Le caractère `t` apparait, tandis que le caractère `e` n'apparait pas.
#
# Écrire une fonction `est_present` qui indique si un caractère apparait dans une chaine, passés en paramètre.
#
# __N.B : Il est possible de faire appel à la fonction `indice` ou `nombre_occurrence` définies dans les exercices précédents.__

# %%
# Réponse

# %% [markdown]
# ## Exercice 4. Chiffre
#
# Écrire une fonction `est_chiffre` qui indique si un `caractère` passé en paramètre est un chiffre ou non.
#
#
# _Exemples d'utilisation :_
#
# ```python
# >>> est_chiffre("0")
# True
# >>> est_chiffre("T")
# False
# >>> est_chiffre("O")
# False
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 5. Plaque d'immatriculation
#
# Depuis le 16 novembre 2010, les plaques d'immatriculation belge sont au format :  un chiffre + 3 lettres + 3 chiffres.
#
# Exemple :
#
# ![Une plaque d'immatriculation belge](https://upload.wikimedia.org/wikipedia/commons/2/20/PlaqueBE1Q.png)
#
# _Source : Wikipedia_
#
# Écrire un prédicat `est_valide` qui prend une plaque d'immatriculation sous la forme d'une chaine de caractères et renvoie True si le numéro de plaque est au bon format, False sinon.

# %% [markdown]
# _Exemples d'utilisation :_
#
# ```python
# >>> est_valide('1-QAA-620')
# True
# >>> est_valide('1-QAA*620')
# False
# >>> est_valide('3-QA1-620')
# False
# ```
#
# __N.B : Il est possible de faire appel au prédicat `est_chiffre` définie dans l'exercice précédent.__

# %%
# Réponse

# %% [markdown]
# ## Exercice 6. Factorielle
#
# En mathématiques, la factorielle d'un entier naturel $n$, noté $n!$ est le produit des nombres entiers strictement positifs inférieurs ou égaux à $n$.
#
# Exemples:
#
# - factorielle de 5: $5! = 5\times4\times3\times2\times1 = 120$
# - factorielle de 10: $10! = 10\times9\times8\times7\times6\times5\times4\times3\times2\times1 = 3628800$
# - factorielle de 0: $0! = 1$ (Par convention)
#
# Écrire la fonction Python pour calculer la `factorielle` d'un nombre `n` (un entier positif) passé en paramètre.

# %%
# Réponse

# %% [markdown]
# ## Exercice 7. Nombre premier
#
# Un nombre premier est un nombre naturel supérieur à 1, qui n'a pas de diviseur positif autre que 1 et lui-même.
#
# Pour tester la primalité de $n$, on vérifie s’il est divisible par l’un des entiers compris au sens large entre 2 et $n-1$. Si la réponse est négative, alors $n$ est premier, sinon il est composé.
#
# Écrire un prédicat `est_premier` qui prend un nombre en paramètre et vérifiez si le nombre est premier ou non.
#
# _Exemples d'utilisation :_
#
# ```python
# >>> est_premier(2)
# True
# >>> est_premier(3)
# True
# >>> est_premier(4)
# False
# >>> est_premier(5)
# False
# ```

# %%
# Réponse
