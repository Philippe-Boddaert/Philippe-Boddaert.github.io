# %% [markdown]
# # Exercices - Les variables

# %% [markdown]
# ## Exercice 1
#
# On considère le programme Python suivant.
#
# ```python
# a = 8
# b = 3
# a = a - 4
# b = 2 * b
# a = a + b
# print(a)
# ```
#
# 1. Combien de variables sont utilisées ?
# 2. (__Sans exécuter le code__) Quelle est la valeur finale de la variable `a` ? Vérifier.
# 3. Il est possible d’afficher plusieurs valeurs avec la fonction `print`. Par exemple, si on veut afficher les valeurs des variables `a` et `b` on écrit simplement `print(a, b)`. Modifiez la dernière ligne du programme et exécutez-le.

# %% [markdown]
# Réponse ici

# %% [markdown]
# ## Exercice 2
#
# On considère le programme de calcul suivant.
#
# - a prend la valeur 5
# - Multiplier a par 3
# - Soustraire 4 au résultat
# - Elever le résultat au carré
# - Afficher le résultat
#
# Écrire un programme Python permettant de coder ce programme de calcul. Vérifiez ensuite en l'exécutant.

# %%
# Réponse

# %% [markdown]
# ## Exercice 3
#
# L’indice de masse corporelle (IMC) est le seul indice validé par l’Organisation mondiale de la santé pour évaluer les éventuels risques pour la santé.
#
# L'IMC est le rapport entre le poids (en Kg) et le carré de la taille (en $m^2$).
#
# Exemple : Une personne mesure 170cm pour un poids de 3/4 de quintal. Son IMC est de 25.95.
#
# Écrire un programme permettant de calculer l'IMC.
#
#
# __Indications__ : Un graphique d'interprétation de l'IMC.
#
# ![imc.png](attachment:imc.png)
# Source : Catherine CLAVERY - stock.adobe.

# %%
# Réponse

# %% [markdown]
# ## Exercice 4
#
# À partir de deux variables `prenom` et `nom`, afficher les initiales (par exemple LM pour Léa Martin).

# %%
# Réponse

# %% [markdown]
# ## Exercice 5
#
# L'identifiant d'accès au réseau du lycée est construit de la manière suivante : initiale du prénom puis les 8 premiers caractères du nom puis le nombre de lettres du prénom.
#
# Exemple : Alexandre Lecouturier → ALecoutur9
#
# A partir de deux variables `prenom` et `nom`, construire l'identifiant.

# %%
# Réponse

# %% [markdown]
# ## Exercice 6
#
# ![Triangle rectangle, Source : Wikipedia](https://upload.wikimedia.org/wikipedia/commons/8/85/Triangle_aire.png)
#
# Écrire un programme qui, à partir de 2 entiers a et h représentant respectivement la base et la hauteur du triangle , calcule et afficher l'aire du triangle.
#
# Exemple : Pour un triangle rectangle dont la base a = 14 et la hauteur h = 25, l'aire est 175.
#
# __Indications__ : [Calcul de l'aire d'un triangle quelconque](https://fr.wikipedia.org/wiki/Aire_d%27un_triangle)

# %%
# Réponse
