# %% [markdown]
# # Exercices - Les boucles bornées (`FOR`)

# %% [markdown]
# ## Exercice 1. La punition
#
# Écrire un programme Python qui permet d'afficher une punition.
#
# La punition consiste à écrire 100 fois : "Je ne discuterai plus avec mon camarade de classe pendant les cours"

# %%
# Réponse

# %% [markdown]
# ## Exercice 2. Affichage d'un compteur
#
# Écrire le code Python permettant d’afficher cette sortie avec une boucle for:
# ```txt
# 0
# 1
# 2
# 3
# 4
# 5
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 3. Affichage d'un compteur (Nombres pairs)
#
# Écrire le code Python permettant d’afficher cette sortie avec une boucle for:
# ```txt
# 2
# 4
# 6
# 8
# 10
# Goodbye!
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 4. Affichage d'un compte à rebours
#
# Écrire le code Python permettant d’afficher cette sortie avec une boucle for:
# ```txt
# Hello !
# 5
# 4
# 3
# 2
# 1
# 0
# Goodbye!
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 5. Table de Multiplication
#
# 1. Recopier le programme suivant :
#
# ```python
# nombre = int(input("De quel nombre voulez-vous la table de multiplication ? "))
#
# for compteur in range(10):
# 	print(nombre)
# ```
#
# 2. Modifier ce programme pour qu'il affiche la table de multiplication du nombre demandé, de 0 à 10.
#
# Par exemple, si l'utilisateur donne la valeur 6, le programme doit afficher :
# ```txt
# 0 x 6 = 0
# 1 x 6 = 6
# 2 x 6 = 12
# 3 x 6 = 18
# 4 x 6 = 24
# 5 x 6 = 30
# 6 x 6 = 36
# 7 x 6 = 42
# 8 x 6 = 48
# 9 x 6 = 54
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 6. Somme des premiers entiers
#
# Écrire une boucle for qui calcule la somme des entiers de 1 à `fin`, inclus.
#
# `fin` est une variable dont la valeur est entrée par l’utilisateur avant la boucle for.
#
# Ainsi, par exemple, si `fin` à pour valeur 6, votre code doit afficher le résultat: 21,  car 1 + 2 + 3 + 4 + 5 + 6 = 21.

# %%
# Réponse

# %% [markdown]
# ## Exercice 7. Problème de l'échiquier de Sissa
#
# Selon [la légende](https://fr.wikipedia.org/wiki/Problème_de_l'échiquier_de_Sissa), pour remercier l'inventeur des échecs Sissa, le roi lui demanda de choisir sa récompense. Sissa demanda alors du riz : __un grain sur la première case, deux grains sur la seconde case, quatre grains sur la troisième case, huit grains sur la quatrième, et ainsi de suite jusqu'à la dernière case du jeu d'échec__. Le roi accepta.
#
# On se demande combien de grains seront posés sur la dernière case du plateau d'échecs (qui en compte 64).
#
# Pour résoudre ce problème, on peut utiliser le programme suivant :
#
# ```python
# grains = 1
#
# for i in range(???):
#     grains = ???
#
# print("Nombre de grains sur la dernière case :", grains)
# ```
#
# 1. Compléter ce programme, et exécutez-le.
# 2. Combien de grains de riz y aura-t-il sur la dernière case de l'échiquier ?

# %%
# Réponse

# %% [markdown]
# ## Exercice 8. Tortue qui dessine
#
# Le module `turtle` (*tortue*) permet de dessiner avec Python.
#
# Dans cet exercice on veut écrire un programme qui permet de dessiner des formes géométriques. Voici le code incomplet du programme.
#
# ```python
# import turtle  # pour utiliser le module turtle
#
# """Fonction qui manipule une tortue dessinatrice"""
# turtle.forward(100)  # pour avancer de 100 pixels
# turtle.left(90)  # pour tourner de 90° à gauche
# turtle.forward(100)
# turtle.left(90)
#
# turtle.done()  # pour afficher le dessin
# ```
# 1. Modifier le programme afin que la tortue dessine un `carré`, en utilisant une boucle `for`.
# 2. Modifier le programme afin que la tortue dessine un `triangle`, en utilisant une boucle `for`.
# 3. Modifier le programme afin que la tortue dessine un `octogone`, en utilisant une boucle `for`.

# %%
# Réponse
