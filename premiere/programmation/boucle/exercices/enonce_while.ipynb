# %% [markdown]
# # Exercices - Les boucles non bornées (`WHILE`)

# %% [markdown]
# ## Exercice 1. Compte à rebours
#
# Écrire un programme, utilisant une __boucle non bornée__ et affiche un décompte jusque 0.
#
# La valeur de `départ` est égale à 10.

# %%
# Réponse

# %% [markdown]
# ## Exercice 2. Indice de la première voyelle
#
# 1. Écrire un programme qui étant donné une variable `nom` égale au vôtre, s'arrête lorque qu'une voyelle est détectée et affiche l'indice de cette voyelle dans la chaîne de caractères.
#
# __Code à compléter__ :
# ```python
# nom = "BODDAERT"
# indice = 0
# #
# # code du programme
# #
# print(indice)
# ```
#
# 2. Que se passe-t-il si le nom ne contient aucune voyelle ? (Exemple : "PFFF")
# 3. Quelle solution permet de gérer ce cas ?

# %%
# Réponse

# %% [markdown]
# ## Exercice 3. La tortue dessinatrice
#
# En reprenant les fonctions `forward`, `left`et `done` de la tortue, vus dans les exercices sur la boucle `FOR`, écrire un programme permettant d'obtenir la figure suivante :
#
# 1. La solution peut s'écrire sous la forme de l'algorithme suivant :
#
# ```txt
# longueur <- 100
# Tant que longueur > 0
# 	la tortue avance sur une distance de longueur
# 	la tortue tourne de 90° à gauche
# 	longueur diminue de 10
# Fin du tant que
# ```
#
# 2. Êtes-vous certain que la boucle s'arrête à un moment donné ? Pourquoi ?

# %%
# Réponse

# %% [markdown]
# ## Exercice 4. Algorithme mystère
#
# ```txt
# Soit l'algorithme Mystère:
# - Entrées : a, un entier naturel et positif.
# - Sortie : resultat, une chaine de caractères.
# Début
#     1. resultat <- "" # Chaine de caractères vides
#     2. quotient <- a
#     3. Tant que quotient > 0 faire
#     4.  |   reste <- quotient % 2
#     5.  |   resultat <- reste + resultat
#     6.  |   quotient <- quotient // 2
#     7. Fin
#     8. Afficher(resultat)
# Fin
# ```

# %% [markdown]
# 1. Compléter le tableau de valeurs suivant pour une entrée de l'algorithme `a = 6`.
# | quotient (en début de boucle) | resultat (en début de boucle) | Valeur de la condition | reste | resultat (en fin de la boucle) | quotient (en fin de boucle) |
# | :--: | :--: | :--: | :--: | :--: | :--: |
# | 6 | "" | Vrai | 0 | "0" | 3 |
# | 3 | ... | ... | ... | ... | ... |
# | ... | ... | ... | ... | ... | ... |
# | ... | ... | ... | ... | ... | ... |
# 2. Recopier et compléter le tableau de valeurs pour une entrée de l'algorithme `a = 14`
# 3. Que fait l'algorithme mystère pour l'entier donné en entrée ?

# %% [markdown]
# Réponse ici

# %% [markdown]
# ## Exercice 5. Implémentation de l'algorithme mystère
#
# Coder en python l'algorithme mystère de l'exercice précédent.

# %%
# Réponse
