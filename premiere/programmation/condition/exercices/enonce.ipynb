# %% [markdown]
# # Exercices - Les instructions conditionnelles

# %% [markdown]
# ## Exercice 1. Minimum entre 2 entiers
#
# Écrire un programme qui demande 2 entiers `a` et `b` de manières consécutives et affiche le minimum des 2 entiers

# %%
# Réponse

# %% [markdown]
# ## Exercice 2. Voyelle ou Consonne
#
# Écrire un programme pour vérifier si un caractère saisi par l'utilisateur est une voyelle ou une consonne.
# Le programme affiche "Voyelle" dans le cas où le caractère l'est et "Consonne" sinon.
#
# __N.B__ : On considère que les caractères sont en minuscules.
#
# __N.B__ : L'opérateur `in` permet de tester si un caractère appartient à une chaîne.

# %%
# Réponse

# %% [markdown]
# ## Exercice 3. Jour de la semaine
#
# Écrire un programme qui prend en entrée un numéro du jour de la semaine (1-7) et affiche le nom du jour de la semaine correspondant.
#
# __N.B__ : On considère qu'une semaine commence le Lundi.

# %%
# Réponse

# %% [markdown]
# ## Exercice 4. Nombre divisible par 3 et 13
#
# Écrire un programme pour vérifier si un nombre saisi par un utilisateur est divisible par 3 et 13 ou non.
#
# __Exemple__ :
# - 39 est divisible par 3 et 13,
# - 27 est divisible uniquement par 3.

# %%
# Réponse

# %% [markdown]
# ## Exercice 5. Taille et Yoda
#
# Soit l'algorithme qui détermine la réponse de Yoda en fonction de la taille qui lui est communiquée :
#
# ```txt
#   Demander la taille
#   Si la taille est entre 0.80m et 1m20 exclu alors
#     la réponse est "Maitre, ce n'est pas la taille qui compte"
#   Sinon si la taille est entre 1m20 et 1m80 exclu alors
#     la réponse est "Maitre, vous vous prenez pour Luc Skywalker"
#   Sinon si la taille est supérieure ou égale à 1m80 alors
# 	la réponse est "Maître, vous vous prenez pour Chewbacca"
#   Sinon la réponse est "Maitre, vous vous sous-estimez"
# ```
#
# Compléter le code suivant pour qu'il implémente l'algorithme ci-dessus :
#
# ```python
# taille = float(input('Mesures combien-tu ?'))
# ...
# print(reponse)
# ```

# %%
# Réponse

# %% [markdown]
# ## Exercice 6. IMC
#
# L’indice de masse corporelle (IMC) est le seul indice validé par l’Organisation mondiale de la santé pour évaluer la corpulence d’un individu et donc les éventuels risques pour la santé.
#
# La formule de calcul a été vu lors d'une activité précédente.
#
# L'OMS fournit l'interprétation suivante de l'état de santé en fonction de l'IMC :
#
# | Indice de masse corporelle (IMC) | Interprétation (d'après l'OMS) |
# | :--: | :--: |
# | moins de 18,5	| Insuffisance pondérale (maigreur) |
# | 18,5 à 25 |	Corpulence normale |
# | 25 à 30 | Surpoids |
# | 30 à 35 | Obésité modérée |
# | 35 à 40 | Obésité sévère |
# | plus de 40	| Obésité morbide ou massive |

# %% [markdown]
# Voici une liste de caractéristiques de célébrités anonymisées.
#
# | Célébrité | Poids (en cm) | Taille (en kg) | Interprétation |
# | :--: | :--: | :--: | :--: |
# | B | 169 | 56 | |
# | E | 157 | 48 | |
# | A | 175 | 90 | |
# | M | 205 | 200 | |
# | V | 163 | 42 | |
# | P | 170 | 75 | |
# | S | 191 | 113 | |
#
# 1. Écrire un programme qui permet de calculer l'IMC en fonction de la taille et le poids renseigné par l'utilisateur et affiche l'imc et son interprétation.
#
# 2. Compléter le tableau en fonction de vos résultats.

# %%
# Réponse
