# %% [markdown]
# # Comparaison liste chaînée et tableau

# %% [markdown]
# ## 1. Contexte
#
# Nous allons comparer l'efficacité des deux structures en terme de __temps__ en réalisant un grand nombre d'insertions en tête puis un grand nombre d'accès à un indice donné pour chacune des structures.

# %% [markdown]
# ## 2. Mode opératoire
#
# 💻 __À Faire__ : Importer votre module `Maillon`, en cliquant sur "Fichier" > "Ouvrir...", sélectionner votre fichier `maillon.py` et "Installer le module"

# %% [markdown]
# ## 3. Génération des structures
#
# Pour commencer, codez les deux fonctions ci-dessous qui vont nous permettre de créer des listes chaînées ou des liste Python :
#
# ```python
# def generer_liste_chainee(taille):
#     '''
#     Renvoie une liste chainée de longueur taille comportant des valeurs aléatoires
#     :param taille: (int) la taille de la liste chainée
#     :return: (Maillon) Une liste chainée de longueur taille
#     '''
#     chaine = Maillon()
#
#
# def generer_tableau(taille):
#     '''
#     Renvoie un tableau de longueur taille comportant des valeurs aléatoires
#     :param taille: (int) la taille du tableau
#     :return: (list) Un tableau de longueur taille
#     '''
#     tableau = []
#     ...
# ```

# %%
# Réponse

# %% [markdown]
# ## 4. Comparaison des temps d'ajout en tête
#
# La fonction `comparer_ajout(taille, nb_ajout)` doit réaliser les tâches suivantes :
#
# 1. elle génére tout d'abord une liste chaînée de longueur _taille_.
# 2. ensuite elle utilise le module `time` pour obtenir l'instant de départ :
#
#     ```python
#     debut = time.time()
#     ############Algo
#     ...
#     ################
#     fin = time.time()
#     duree_chaine = fin - debut
#     ```
#
# 3. elle poursuit en ajoutant __en tête__ _nbre_ajouts_ valeurs (par exemple 'a') à la liste chaînée.
# 4. elle utilise le module `time` pour mesurer l'instant où la boucle prend fin.
# 5. elle obtient le temps mis par la boucle pour la liste chaînée par simple soustraction _fin - debut_.
# 6. elle refait la même chose, à partir de l'étape 1. avec un tableau
# 7. pour finir elle renvoie le tuple `duree_chaine, duree_tableau`.

# %% [markdown]
# 💻 __À Faire__ : Programmer le corps de la fonction
#
# ```python
# def comparer_ajout(taille, nb_ajout):
#     '''
#     Renvoie les temps mis par une liste chainée puis par un tableau
#     pour réaliser nb_ajout en tête de structures de longueur taille
#     :param taille: (int) La taille de la structure
#     :param nb_ajout: (int) Le nombre d'ajout à réaliser
#     return (tuple) duree_chaine, duree_tableau
#     '''
# ```

# %%
# Réponse

# %% [markdown]
# ❓__À Faire__ : Comparer les deux structures pour 1000 ajouts en tête :
#   - avec des structures de petites longueurs (taille = 100)
#   - avec des structures de grandes longueurs (taille = 1000000)
#
# __Qu'en concluez-vous ?__

# %%
# Réponse

# %% [markdown]
# ## 5. Comparaison des temps d'insertion à une position d'un élément
#
# De la même façon, définir la fonction `comparer_insertion(taille, nb_insertion, indice)` qui comparera les temps des deux structures pour insérer à l'indice voulu _nb_insertion_ fois dans des structures de longueur _taille_.
#
# ❓__À Faire__ : Comparer les deux structures pour 1000 insertions :
#   - avec des structures de petites ou grandes longueurs (100, 100000)
#   - Considérer des indices faibles ou grands (0, taille //2, taille -1)
#
# __Qu'en concluez-vous ?__

# %%
# Réponse

# %%
# Réponse

# %% [markdown]
# ## 6. Comparaison des temps d'accès à un élément
#
# De la même façon, définir la fonction `comparer_acces(taille, nb_acces, indice)` qui comparera les temps des deux structures pour accéder à l'indice voulu _nb_acces_ fois dans des structures de longueur _taille_.
#
# ❓__À Faire__ : Comparer les deux structures pour 1000 accès :
#   - avec des structures de petites ou grandes longueurs (100, 100000)
#   - Considérer des indices faibles ou grands (0, taille //2, taille -1)
#
# __Qu'en concluez-vous ?__

# %%
# Réponse

# %%
# Réponse
