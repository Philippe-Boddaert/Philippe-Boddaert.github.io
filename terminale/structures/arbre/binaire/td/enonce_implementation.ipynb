# %% [markdown]
# # TD - Implémentation des arbres binaires
#
# Nous allons à travers ce TD définir une classe pour un arbre binaire.
#
# 💻 __À Faire :__ Créer le fichier `arbre.py`.

# %% [markdown]
# ## 1.  Initialisation de la classe
#
# Un arbre binaire est définit par la clé de sa racine, son sous-arbre gauche et son sous-arbre droit.
#
# Nous l'initialisons ainsi :
#
# ```python
# class Arbre():
#     '''
#     une classe pour implémenter des arbres de façon récursive
#     '''
#     def __init__(self, etiquette = None, gauche = None, droite = None):
#         '''
#         construit un arbre vide avec un sous-arbre gauche et un sous-arbre droit vides par défaut
#         :param etiquette: (Any) l'étiquette du noeud
#         :param gauche : (Arbre) le sous arbre gauche
#         :param droite : (Arbre) le sous-arbre droit
#         '''
#         self.__etiquette = etiquette
#         self.__gauche = gauche
#         self.__droite = droite
# ```

# %% [markdown]
# 💻 __À Faire 1__: Construire l'arbre ci-dessous en commençant par les feuilles
#
# ![graphviz%20%282%29.png](attachment:graphviz%20%282%29.png)
#
# Pour vous aider, voici un début :
#
# ```python
# >>> a4 = Arbre(4)
# >>> a7 = Arbre(7)
# >>> a6 = Arbre(6, a4, a7)
# >>> ...
# >>> ...
# >>> ...
# >>> racine = ...
# ```

# %%
# Réponse

# %% [markdown]
# ## 2. Prédicats
#
# 💻 __À Faire 2__: Définir et coder le prédicat `est_feuille(self)` qui renvoie `True` si l'Arbre est une feuille et `False` sinon.
#
# __N.B__ : N'oubliez pas la docstring et les doctests.

# %%
# Réponse

# %% [markdown]
# 💻 __À Faire 3__ : Définir et coder le prédicat `est_vide(self)` qui renvoie `True` si l'Arbre est vide et `False` sinon.
#
# __N.B__ : N'oubliez pas la Docstring et un Doctest.

# %%
# Réponse

# %% [markdown]
# ## 3. Accesseurs
#
# 💻 __À Faire 4__ : Compléter les accesseurs ci-dessous.
#
# ```python
# def arbre_gauche(self):
#     '''
#      renvoie le fils gauche de l'arbre. Si ce fils est None, renvoie un Arbre vide.
#      :return: (Arbre)
#     '''
#
# def arbre_droite(self):
#     '''
#     renvoie le fils droit de l'arbre. Si ce fils est None, renvoie un Arbre vide.
#     :return: (Arbre)
#     '''
#
# def renvoyer_etiquette(self):
#     '''
#     renvoie l'étiquette de l'arbre
#     :return: (Any)
#     '''
# ```

# %%
# Réponse

# %% [markdown]
# ## 4. Affichage
#
# Nous allons ici coder la méthode `__str__` pour pouvoir afficher un Arbre.
#
# Nous allons pour cela renvoyer une chaîne de caractères où un arbre est représenté par un triplet (étiquette,  gauche, droite) où :
#
# * `étiquette` est la valeur du noeud de la racine.
# * `gauche` est le sous-arbre gauche.
# * `droite` est le sous-arbre droit.

# %% [markdown]
# Ainsi, l'arbre dessiné ci-dessous est représenté par la chaîne de caractères :
#
# ```python
# (8, (3, (1, ∆, ∆), (6, (4, ∆, ∆), (7, ∆, ∆))), (10, ∆, (14, (13, ∆, ∆), ∆)))
# ```
#
# ![graphviz%20%282%29.png](attachment:graphviz%20%282%29.png)

# %% [markdown]
# La fonction d'affichage est naturellement récursive :
#
# $affichage(arbre) = \left\{ \begin {array} {ll} {~si~arbre~est~vide~:~} renvoyer~'∆'  \\  {sinon~:~} renvoyer~\\ '(' + str(etiquette)~+~', '~+\\ ~affichage(sous-arbre-gauche)~+~', '~+\\~affichage(sous-arbre-droit)~+~')'  \end{array}\right.$

# %% [markdown]
# 💻 __À Faire 5__ : Coder la méthode `__str__(self)` en utilisant la définition récursive ci-dessus.
#
# __N.B__ : Utiliser les méthodes `gauche()` et `droite()` et non pas les attributs correspondants qui, eux, pourraient être `None` et donc ne pas être du type `Arbre`.
#
# ```python
# def __str__(self):
#     '''
#     renvoie une chaîne de caractère représentant l'arbre
#     :return: (str)
#     '''
# ```

# %%
# Réponse

# %% [markdown]
# Pour finir, nous utiliserons la représentation ci-dessous :
#
# ```python
#     def __repr__(self):
#        '''
#        renvoie une chaîne de caractère représentant l'arbre
#        : return (str)
#        '''
#        return self.__str__()
# ```
