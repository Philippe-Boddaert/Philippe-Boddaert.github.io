# %% [markdown]
# # TD - Implémentation des arbres binaires de recherche
#
# Nous allons à travers ce TD définir une classe pour un arbre binaire de recherche.
#
# 💻 __À Faire :__ Créer le fichier `abr.py`.

# %% [markdown]
# ## 1.  Initialisation de la classe
#
# Un ABR est un arbre binaire particulier.
#
# Au départ, il est toujours vide. Par la suite, on va insérer des valeurs dans l'ABR ou vérifier qu'une valeur est déjà présente dans l'ABR en utilisant les algorithmes particuliers des ABR.
#
# Nous allons profiter d'une caractéristique de la programmation orientée objet : __l'héritage__. Cette notion n'est pas au programme de NSI mais elle est pratique et adaptée à notre situation.

# %% [markdown]
# Nous l'initialisons ainsi :
#
# ```python
# from arbre import Arbre
#
# class ABR(Arbre) :
#     '''
#     une classe pour implémenter des arbres binaire de recherche
#     '''
#     def __init__(self, etiquette = None, gauche = None, droite = None):
#         '''
#         construit un arbre vide avec un sous_arbre gauche et un sous arbre droit vides
#         '''
#         # on fait appelle au constructeur de la classe parente, la classe Arbre pour construire un ABR vide :
#         super().__init__(etiquette, gauche, droite)
# ```

# %% [markdown]
# 💻 __À Faire 1__: Exécuter le code suivant. Que constatez-vous ? Où est défini le code des méthodes ?
#
#
# Pour vous aider, voici un début :
#
# ```python
# >>> a = ABR()
# >>> print(a)
# >>> a.est_vide()
# >>> b = ABR(2, ABR(0), ABR(8))
# >>> print(b)
# >>> b.renvoyer_etiquette()
# ```

# %% [markdown]
# Réponse ici

# %% [markdown]
# ## 2. Mutateur
#
# Nous allons avoir besoin d'un mutateur pour la classe ABR.
#
# Un mutateur est une méthode de classe qui modifie les valeurs d'attributs de la classe.
#
# ```python
# def maj(self, cle):
#     self._Arbre__etiquette = cle
#     self._Arbre__gauche = ABR()
#     self._Arbre__droite = ABR()
# ```

# %% [markdown]
# 💻 __À Faire 2__: Copier le code ci-dessous dans la classe `ABR`. Compléter instructions suivantes et vérifier en exécutant les instructions.
#
# ```python
# >>> A = ABR()
# >>> A.est_feuille()
# ???
# >>> A.maj(2)
# >>> A.est_feuille()
# ???
# >>> A.renvoyer_etiquette()
# ???
# >>> type(A.arbre_gauche())
# ???
# ```

# %% [markdown]
# Réponse ici

# %% [markdown]
# ❓__À Faire 3__ : Qu'en déduire sur la signification de  `self._Arbre` ?

# %% [markdown]
# Réponse ici
