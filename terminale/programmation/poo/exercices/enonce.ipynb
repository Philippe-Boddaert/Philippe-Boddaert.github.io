# %% [markdown]
# # Un bouquet de fleurs
#
# ![flowers-7233992_640.jpg](attachment:flowers-7233992_640.jpg)

# %% [markdown]
# __À Faire 1__ : Créer une classe `Fleur` avec les attributs suivants :
#
# - __couleur__ : chaîne de caractère de valeur initiale `blanc`
# - __taille__ : nombre réel de valeur initiale 20 cm
# - __nbr_petales__ : nombre entier de valeur initiale 10
# - __nbr_feuilles__ : nombre entier de valeur initiale 0

# %%
# Réponse

# %% [markdown]
# __À Faire 2__ : Instancier trois objets `Fleur` : __fleur_1__, __fleur_2__, __fleur_3__. Ont-elles les même attributs ? Pourquoi ?

# %%
# Réponse

# %% [markdown]
# __À Faire 3__ : Appliquer les modifications suivantes :
#
# - __fleur_2__ a __8__ pétales rouges, __4__ feuilles et mesure __25__ cm
# - __fleur_3__ a __16__ pétales jaunes, __8__ feuilles et mesure __12__ cm

# %%
# Réponse

# %% [markdown]
# __À Faire 4__ : Afficher la couleur de chaque fleur, puis leur nombre de feuilles.

# %%
# Réponse

# %% [markdown]
# __À Faire 5__ : Créer une liste __bouquet__ contenant les trois fleurs.

# %%
# Réponse

# %% [markdown]
# __À Faire 6__ : Afficher le nombre de pétales de la première fleur contenue dans la liste, puis de la deuxième.

# %%
# Réponse

# %% [markdown]
# __À Faire 7__ : À l’aide d’une boucle `for`, afficher le nombre de pétales de toutes les fleurs de la liste, des deux
# manières possibles.

# %%
# Réponse

# %% [markdown]
# __À Faire 8__ : Créer une méthode `afficher_caracteristiques`, qui affiche les valeurs de tous les attributs d’une
# fleur.

# %%
# Réponse

# %% [markdown]
# __À Faire 9__ : À l’aide d’une boucle `for`, afficher les caractéristiques de toutes les fleurs de la liste.

# %%
# Réponse

# %% [markdown]
# __À Faire 10__ : Créer une méthode `ajouter_petale` qui a pour effet de bord d'ajouter une pétale à la fleur.

# %%
# Réponse

# %% [markdown]
# __À Faire 11__ : Créer une méthode `enlever_petale` qui a pour effet de bord d'enlèver une pétale à la fleur. Si on essaie d’enlever une pétale à une fleur n’en possédants plus, la valeur doit rester nulle.

# %%
# Réponse

# %% [markdown]
# __À Faire 12__ : Créer une méthode `allonger`, de paramètre x, qui a pour effet de bord d'allonger la tige de x cm.

# %%
# Réponse

# %% [markdown]
# __À Faire 13__ : Créer une méthode `pousser`, qui a pour effet de bord d'allonger la tige de 10 %.

# %%
# Réponse

# %% [markdown]
# __À Faire 14__ : Ajouter une précondition vérifiant que le paramètre x est positif ou nul. Dans le cas contraire, une exception est levée avec pour message le paramètre doit être positif ou nul.

# %%
# Réponse

# %% [markdown]
# __À Faire 15__ : Créer une méthode `est_fanee`, qui renvoie True si la fleur ne possède plus de pétale, False
# sinon.

# %%
# Réponse

# %% [markdown]
# __À Faire 16__ : Les couleurs seront maintenant indiquées dans une liste. Faire les modifications nécessaires.

# %%
# Réponse

# %% [markdown]
# __À Faire 17__ :  Créer une classe `Laboratoire` ne possédant pas d’attributs et instancier un
# laboratoire nommé labo.

# %%
# Réponse

# %% [markdown]
# __À Faire 18__ :  Lui ajouter une méthode `croisement` qui prend en paramètre deux objets `Fleur` et qui renvoie
# un nouvel objet `Fleur`. L’attribut couleur de ce nouvel objet est une liste des couleurs de ses fleurs
# parents. Chaque autre attribut sera une moyenne des attributs de ses fleurs parents.

# %%
# Réponse

# %% [markdown]
# __À Faire 19__ :  Créer une méthode `croisement_bouquet` qui prend en paramètre une liste d’objets `Fleur`. La
# méthode renvoie une liste d’objets `Fleur` obtenue avec tous les croisements possibles concaténée à la liste des fleurs parents.

# %%
# Réponse

# %% [markdown]
# __À Faire 20__ :  Afficher les caractéristiques des fleurs du nouveau bouquet à l’aide d’une boucle.

# %%
# Réponse

# %% [markdown]
# __À Faire 21__ :  Créer une méthode `croisement_bouquet_generation` qui prend en paramètre une liste d’objets
# `Fleur` et un paramètre `n`. La fonction renvoie la liste d’objets `Fleur` obtenue après `n` générations de croisements.

# %%
# Réponse

# %% [markdown]
# __À Faire 22__ : Créer une méthode `couleurs_fleur` qui prend en paramètre un objet `Fleur` et qui renvoie un
# dictionnaire ayant comme clés les couleurs d’un objet `Fleur` et en valeurs le nombre d’apparition de
# ces couleurs.

# %%
# Réponse

# %% [markdown]
# __À Faire 23__ : Modifier la méthode pour que les valeurs correspondent au taux d’apparition des couleurs dans
# la fleur.

# %%
# Réponse
